# %%
isim = input("İsminiz nedir? ")
# Out:
# İsminiz nedir? Erkan

# %%
print("Merhaba ", isim)
# Out:
# Merhaba  Erkan

# %%
yas = 0

# %%
yas = input("Yaşınız: ")
# Out:
# Yaşınız: 25

# %%
print("Merhaba", isim, " yaşınız: ", yas)
# Out:
# Merhaba Erkan  yaşınız:  25

# %%
print("Merhaba", isim, 2019 - yas, " yılında doğmuş olmalısınız.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6dc3eba1c0c7> in <module>
# ----> 1 print("Merhaba", isim, 2019 - yas, " yılında doğmuş olmalısınız.")
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# Alınan girdiler string türündedir.

# %%
print("Merhaba", isim, 2019 - int(yas), " yılında doğmuş olmalısınız.")
# Out:
# Merhaba Erkan 1994  yılında doğmuş olmalısınız.

# %%
kırkbir = int("kirk")
type(kırkbir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b474ef8c65c2> in <module>
# ----> 1 kırkbir = int("kirk")
#       2 type(kırkbir)
#
# ValueError: invalid literal for int() with base 10: 'kirk'

# %% [markdown]
# # Ödev-1

# %% [markdown]
#     Kullanıcıdan 2 rakam alan ve toplamını ekrana yazan bir python programı yazınız.

# %% [markdown]
# # Tek input ile birden fazla rakam alarak listeye aktarma

# %%
import re
a = input("Boşluk bırakarak giriniz: ")
a = list(re.findall(r"[\w']+", a)) # Birden fazla çeşitli paternlere göre ayırma yapar
indeks = 0
for i in a:
    a[indeks] = int(i)
    indeks +=1
# Out:
# Boşluk bırakarak giriniz: 2 3 4

# %%
a
# Out:
# [2, 3, 4]
