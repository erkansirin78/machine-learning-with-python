# %%
import pandas as pd
df = pd.read_csv("D:/Datasets/simple_data.csv")

# %%
df.head()
# Out:
#    sirano     isim  yas       meslek     sehir  aylik_gelir
# 0       1    Cemal   35         Isci    Ankara         3500
# 1       2    Ceyda   42        Memur   Kayseri         4200
# 2       3    Timur   30     Müzisyen  Istanbul         9000
# 3       4    Burcu   29  Pazarlamaci    Ankara         4200
# 4       5  Yasemin   23          NaN     Bursa         4800

# %% [markdown]
# # drop() ile sütun silmek

# %%
df.drop('yas', axis=1, inplace=True)

# %%
df.head()
# Out:
#    sirano     isim       meslek     sehir  aylik_gelir
# 0       1    Cemal         Isci    Ankara         3500
# 1       2    Ceyda        Memur   Kayseri         4200
# 2       3    Timur     Müzisyen  Istanbul         9000
# 3       4    Burcu  Pazarlamaci    Ankara         4200
# 4       5  Yasemin          NaN     Bursa         4800

# %% [markdown]
# <h3 style="color:red";>inplace True işlemlerini bir defa yapabiliriz. Çünkü bellekte veri değişiyor.</h3>
# <h3>Yukarıda kulandığımız axis=1 silmenin sütun bazlı olacağını inplace=True ise
# silmenin gerçekten bu dataframe üzerinde gerçekleşeceğini gösterir</h3>

# %%
df.head()
# Out:
#    sirano     isim       meslek     sehir  aylik_gelir
# 0       1    Cemal         Isci    Ankara         3500
# 1       2    Ceyda        Memur   Kayseri         4200
# 2       3    Timur     Müzisyen  Istanbul         9000
# 3       4    Burcu  Pazarlamaci    Ankara         4200
# 4       5  Yasemin          NaN     Bursa         4800

# %%
# Veri okuma esnasında da drop kullanabiliriz
df = pd.read_csv("D:/Datasets/simple_data.csv").drop('yas', axis=1)
df.head()
# Out:
#    sirano     isim       meslek     sehir  aylik_gelir
# 0       1    Cemal         Isci    Ankara         3500
# 1       2    Ceyda        Memur   Kayseri         4200
# 2       3    Timur     Müzisyen  Istanbul         9000
# 3       4    Burcu  Pazarlamaci    Ankara         4200
# 4       5  Yasemin          NaN     Bursa         4800

# %%
df.head(20)
# Out:
#     sirano      isim       meslek     sehir  aylik_gelir
# 0        1     Cemal         Isci    Ankara         3500
# 1        2     Ceyda        Memur   Kayseri         4200
# 2        3     Timur     Müzisyen  Istanbul         9000
# 3        4     Burcu  Pazarlamaci    Ankara         4200
# 4        5   Yasemin          NaN     Bursa         4800
# 5        6       Ali        Memur    Ankara         4250
# 6        7     Dilek  Pazarlamaci  Istanbul         7300
# 7        8     Murat     Müzisyen  Istanbul        12000
# 8        9     Ahmet       Doktor    Ankara        18000
# 9       10  Muhittin       Berber  Istanbul        12000
# 10      11  Hicaziye   Tuhafiyeci    Ankara         4800
# 11      12     Harun      Tornacı    Ankara         4200
# 12      13     Hakkı        Memur     Çorum         3750
# 13      14   Gülizar       Doktor     İzmir        14250
# 14      15    Şehmuz          NaN    Ankara         8700
# ...

# %% [markdown]
# # Tekrarlayan satırları bir arada toplama duplicated()

# %%
# tekrarlanan satırları görmek
duplicate_rows_df = df[ df.duplicated() ]
duplicate_rows_df.head()
# Out:
#     sirano    isim  meslek   sehir  aylik_gelir
# 16      16  Gençay  Berber  Ankara         8800

# %% [markdown]
# # drop_duplicates()

# %%
# Yukarıda 16. indekste bulunan satır tekrarlanıyor (15 ile tekrarlanmış)
df.drop_duplicates(inplace=True)

# %%
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df.head()
# Out:
# Empty DataFrame
# Columns: [sirano, isim, meslek, sehir, aylik_gelir]
# Index: []

# %% [markdown]
# # drop() ile satır silmek

# %%
# 5 ve 7. satırları silmek
df.drop([5, 7], axis=0, inplace=True)

# %%
df
# Out:
#     sirano      isim       meslek     sehir  aylik_gelir
# 0        1     Cemal         Isci    Ankara         3500
# 1        2     Ceyda        Memur   Kayseri         4200
# 2        3     Timur     Müzisyen  Istanbul         9000
# 3        4     Burcu  Pazarlamaci    Ankara         4200
# 4        5   Yasemin          NaN     Bursa         4800
# 6        7     Dilek  Pazarlamaci  Istanbul         7300
# 8        9     Ahmet       Doktor    Ankara        18000
# 9       10  Muhittin       Berber  Istanbul        12000
# 10      11  Hicaziye   Tuhafiyeci    Ankara         4800
# 11      12     Harun      Tornacı    Ankara         4200
# 12      13     Hakkı        Memur     Çorum         3750
# 13      14   Gülizar       Doktor     İzmir        14250
# 14      15    Şehmuz          NaN    Ankara         8700
# 15      16    Gençay       Berber    Ankara         8800

# %% [markdown]
# # Bir aralıktaki tüm satırları silmek

# %%
df = pd.read_csv("D:/Datasets/simple_data.csv")

# %%
# 5 ile 10 indeks arasındakilerin hepsini silmek
silinecek = list(range(5,11))
df.drop(silinecek, axis=0, inplace=True)

# %%
df.head(20)
# Out:
#     sirano     isim  yas       meslek     sehir  aylik_gelir
# 0        1    Cemal   35         Isci    Ankara         3500
# 1        2    Ceyda   42        Memur   Kayseri         4200
# 2        3    Timur   30     Müzisyen  Istanbul         9000
# 3        4    Burcu   29  Pazarlamaci    Ankara         4200
# 4        5  Yasemin   23          NaN     Bursa         4800
# 11      12    Harun   43      Tornacı    Ankara         4200
# 12      13    Hakkı   33        Memur     Çorum         3750
# 13      14  Gülizar   37       Doktor     İzmir        14250
# 14      15   Şehmuz   41          NaN    Ankara         8700
# 15      16   Gençay   46       Berber    Ankara         8800
# 16      16   Gençay   46       Berber    Ankara         8800
